# %% [markdown]
# <a href="https://colab.research.google.com/github/iamvarshag/Bio-infomatics/blob/Bioinfoexp/Genome_Assembly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update
# !apt-get install fastqc
# !apt-get install velvet
# !wget 'https://zenodo.org/record/582600/files/mutant_R1.fastq'
# !wget 'https://zenodo.org/record/582600/files/mutant_R2.fastq'
import os
from google.colab import files
get_ipython().system("fastqc mutant_R1.fastq")
files.download('mutant_R1_fastqc.html')
get_ipython().system("fastqc mutant_R2.fastq")
files.download('mutant_R2_fastqc.html')
# !mkdir assembly_module
# !cd assembly_module
# !mkdir data
# !cd data
get_ipython().system("velveth ASM_NAME 31 -short -separate -fastq mutant_R1.fastq mutant_R2.fastq")
get_ipython().system("velvetg ASM_NAME")
# Out:
# Get:1 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [354 B]
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,618 kB]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3,637 kB]
# ...
